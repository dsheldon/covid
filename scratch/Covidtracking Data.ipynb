# %%
import os
import sys
parent = os.path.dirname(os.path.abspath(os.curdir))
sys.path.append(parent)

import pandas as pd
import numpy as np
import covidtracking
import matplotlib.pyplot as plt

start = pd.to_datetime('2020-03-04')
US = covidtracking.load_us()

# %%
for state in ['MA', 'WA', 'NY', 'CA']:
    cols = ['positive', 'total']
    US[state][start:].plot(y=cols, style='-o')
    plt.yscale('log')
    plt.title(state)
    plt.show()

    cols = ['positive']
    rate = US[state].loc[start:, cols].apply(np.log).diff().apply(np.exp)
    ax = rate.plot(style='-o')
    plt.title(f'{state} - day over day growth')
    plt.ylim([0, 2])
    l2 = plt.axhline(1.33)
    plt.legend([ax.lines[0]] + [l2], ['rate', '1.33'])
    plt.show()

# %%
cols = ['confirmed', 'death', 'hospitalizedCumulative']

states = US.columns.unique(level=0)
#states = ['WA']

target = 'hospitalizedCumulative'

shifts = [0, 5, 10]
scales = [0.1, 0.2]

for state in states:
    data = {col: US[state][col] for col in cols}
    df = pd.DataFrame(data = data)
    predictors = []
    for shift in shifts:
        for scale in scales:
            name = f'{scale} x confirmed(t-{shift})'
            df[name] = scale*df.confirmed.shift(shift)
            predictors.append(name)
    
    fig, ax = plt.subplots()
    df.plot(style='--.', y = predictors, ax=ax, alpha=0.8)
    df.plot(style='-o', y = target, ax=ax, color='k', linewidth=3)
    plt.title(state)
    plt.yscale('log')

    filename = f'vis2/{target}_{state}.png'
    plt.savefig(filename)
    
    plt.show()
# Out:
# /Users/sheldon/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4664             try_not_ender(instring, loc)
# -> 4665         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4666         try:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4019         # pre-parsed the string as part of our And pre-parsing
# -> 4020         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4021         errorStop = False
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1672             else:
# -> 1673                 loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1674
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1672             else:
# -> 1673                 loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1674
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    3310         if not result:
# -> 3311             raise ParseException(instring, loc, self.errmsg, self)
#    3312
#
# ParseException: Expected _ | ^, found '}'  (at char 19), (line:1, col:20)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c08c4c9e4b58> in <module>
#      28     plt.savefig(filename)
#      29
# ---> 30     plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </Users/sheldon/opt/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1203         ticks_to_draw = self._update_ticks()
#    1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1205                                                                 renderer)
#    1206
#    1207         for tick in ticks_to_draw:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
#    1149         return ([tick.label1.get_window_extent(renderer)
# -> 1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#    1152                  for tick in ticks if tick.label2.get_visible()])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
#    1149         return ([tick.label1.get_window_extent(renderer)
# -> 1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#    1152                  for tick in ticks if tick.label2.get_visible()])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     888             raise RuntimeError('Cannot get window extent w/o renderer')
#     889
# --> 890         bbox, info, descent = self._get_layout(self._renderer)
#     891         x, y = self.get_unitless_position()
#     892         x, y = self.get_transform().transform_point((x, y))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     296             if clean_line:
#     297                 w, h, d = renderer.get_text_width_height_descent(
# --> 298                     clean_line, self._fontproperties, ismath=ismath)
#     299             else:
#     300                 w = h = d = 0
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     204         if ismath:
#     205             ox, oy, width, height, descent, fonts, used_characters = \
# --> 206                 self.mathtext_parser.parse(s, self.dpi, prop)
#     207             return width, height, descent
#     208
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mathtext.py in parse(self, s, dpi, prop)
#    3369             self.__class__._parser = Parser()
#    3370
# -> 3371         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3372         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3373         return font_output.get_results(box)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2596         self._em_width_cache = {}
#    2597         try:
# -> 2598             result = self._expression.parseString(s)
#    2599         except ParseBaseException as err:
#    2600             raise ValueError("\n".join(["",
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1927             instring = instring.expandtabs()
#    1928         try:
# -> 1929             loc, tokens = self._parse(instring, 0)
#    1930             if parseAll:
#    1931                 loc = self.preParse(instring, loc)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4035                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4036             else:
# -> 4037                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4038             if exprtokens or exprtokens.haskeys():
#    4039                 resultlist += exprtokens
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4747     def parseImpl(self, instring, loc, doActions=True):
#    4748         try:
# -> 4749             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4750         except (ParseException, IndexError):
#    4751             return loc, []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4663         if check_ender:
#    4664             try_not_ender(instring, loc)
# -> 4665         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4666         try:
#    4667             hasIgnoreExprs = (not not self.ignoreExprs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4018         # pass False as last arg to _parse for first element, since we already
#    4019         # pre-parsed the string as part of our And pre-parsing
# -> 4020         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4021         errorStop = False
#    4022         for e in self.exprs[1:]:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1700                 for fn in self.parseAction:
#    1701                     try:
# -> 1702                         tokens = fn(instring, tokensStart, retTokens)
#    1703                     except IndexError as parse_action_exc:
#    1704                         exc = ParseException("exception raised in parse action")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in wrapper(*args)
#    1306         while 1:
#    1307             try:
# -> 1308                 ret = func(*args[limit[0]:])
#    1309                 foundArity[0] = True
#    1310                 return ret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mathtext.py in math_string(self, s, loc, toks)
#    2671
#    2672     def math_string(self, s, loc, toks):
# -> 2673         return self._math_expression.parseString(toks[0][1:-1])
#    2674
#    2675     def math(self, s, loc, toks):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1927             instring = instring.expandtabs()
#    1928         try:
# -> 1929             loc, tokens = self._parse(instring, 0)
#    1930             if parseAll:
#    1931                 loc = self.preParse(instring, loc)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4663         if check_ender:
#    4664             try_not_ender(instring, loc)
# -> 4665         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4666         try:
#    4667             hasIgnoreExprs = (not not self.ignoreExprs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4018         # pass False as last arg to _parse for first element, since we already
#    4019         # pre-parsed the string as part of our And pre-parsing
# -> 4020         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4021         errorStop = False
#    4022         for e in self.exprs[1:]:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4815     def parseImpl(self, instring, loc, doActions=True):
#    4816         try:
# -> 4817             loc, tokens = self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4818         except (ParseException, IndexError):
#    4819             if self.defaultValue is not self.__optionalNotMatched:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4035                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4036             else:
# -> 4037                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4038             if exprtokens or exprtokens.haskeys():
#    4039                 resultlist += exprtokens
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4747     def parseImpl(self, instring, loc, doActions=True):
#    4748         try:
# -> 4749             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4750         except (ParseException, IndexError):
#    4751             return loc, []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4673                 else:
#    4674                     preloc = loc
# -> 4675                 loc, tmptokens = self_expr_parse(instring, preloc, doActions)
#    4676                 if tmptokens or tmptokens.haskeys():
#    4677                     tokens += tmptokens
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
# ...
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4035                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4036             else:
# -> 4037                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4038             if exprtokens or exprtokens.haskeys():
#    4039                 resultlist += exprtokens
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4747     def parseImpl(self, instring, loc, doActions=True):
#    4748         try:
# -> 4749             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4750         except (ParseException, IndexError):
#    4751             return loc, []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4673                 else:
#    4674                     preloc = loc
# -> 4675                 loc, tmptokens = self_expr_parse(instring, preloc, doActions)
#    4676                 if tmptokens or tmptokens.haskeys():
#    4677                     tokens += tmptokens
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4428     def parseImpl(self, instring, loc, doActions=True):
#    4429         if self.expr is not None:
# -> 4430             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4431         else:
#    4432             raise ParseException("", loc, self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4220         for e in self.exprs:
#    4221             try:
# -> 4222                 ret = e._parse(instring, loc, doActions)
#    4223                 return ret
#    4224             except ParseException as err:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1828                 ParserElement.packrat_cache_stats[MISS] += 1
#    1829                 try:
# -> 1830                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1667             if self.mayIndexError or preloc >= len(instring):
#    1668                 try:
# -> 1669                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1670                 except IndexError:
#    1671                     raise ParseException(instring, len(instring), self.errmsg, self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4035                     raise ParseSyntaxException(instring, len(instring), self.errmsg, self)
#    4036             else:
# -> 4037                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4038             if exprtokens or exprtokens.haskeys():
#    4039                 resultlist += exprtokens
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1831                 except ParseBaseException as pe:
#    1832                     # cache a copy of the exception, without the traceback
# -> 1833                     cache.set(lookup, pe.__class__(*pe.args))
#    1834                     raise
#    1835                 else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyparsing.