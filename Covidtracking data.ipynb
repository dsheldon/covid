# %%
import covidtracking
import matplotlib.pyplot as plt

US = covidtracking.load_us()
US.MA.plot(style='-o')
plt.show()

# %%
import states
traits = states.uga_traits()
display(traits)
# Out:
#                             NAME         capitol    largest_city     under60  \
# postalCode
# AL                       Alabama      Montgomery      Birmingham   3826064.0
# AK                        Alaska          Juneau       Anchorage    606701.0
# AZ                       Arizona         Phoenix         Phoenix   5451912.0
# AR                      Arkansas     Little Rock     Little Rock   2355113.0
# CA                    California      Sacramento     Los Angeles  32027272.0
# CO                      Colorado          Denver          Denver   4507683.0
# CT                   Connecticut        Hartford      Bridgeport   2803163.0
# DE                      Delaware           Dover      Wilmington    729535.0
# DC          District of Columbia             NaN             NaN    573825.0
# FL                       Florida     Tallahassee    Jacksonville  15460904.0
# GA                       Georgia         Atlanta         Atlanta   8441626.0
# ...
